# %%
pip install -qU  langchain langchain-huggingface sentence_transformers
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_huggingface.embeddings import HuggingFaceEmbeddings

# %%
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-mpnet-base-v2")
# Out:
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 6039.12it/s]
# MPNetModel LOAD REPORT from: sentence-transformers/all-mpnet-base-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
text = "document."

# %%
result = embeddings.embed_query(text)

# %%
result
# Out:
# [0.013469857163727283,
#  0.06487338244915009,
#  0.01941676065325737,
#  0.004896286875009537,
#  -0.07187388092279434,
#  0.041483644396066666,
#  0.021042734384536743,
#  0.04369786009192467,
#  -0.06254109740257263,
#  0.0002133088855771348,
#  0.06923415511846542,
#  -0.026232179254293442,
#  0.006068681366741657,
#  -0.03884643688797951,
#  0.013785778544843197,
#  0.00877033919095993,
#  0.006699115503579378,
#  0.016104020178318024,
#  0.014409384690225124,
#  -0.004377161618322134,
#  0.0193865317851305,
#  0.04441767930984497,
#  0.016476919874548912,
#  0.017949208617210388,
#  -0.03883716091513634,
#  -0.032750844955444336,
#  -0.008798009715974331,
#  0.006717632990330458,
#  -0.06133395433425903,
#  -0.034335196018218994,
#  -0.011996744200587273,
#  0.06427067518234253,
#  0.03872232511639595,
#  -0.05037902668118477,
#  2.2511460429086583e-06,
#  -0.024068430066108704,
#  0.0257672518491745,
#  0.017405172809958458,
#  -0.003300438867881894,
#  0.030479714274406433,
# ...

# %%
from langchain_core.vectorstores import InMemoryVectorStore
vector_store = InMemoryVectorStore(embedding=embeddings)

# %%
from langchain_community.document_loaders import PyPDFLoader, TextLoader

# %%
loader2= TextLoader('main.txt')
doc2= loader2.load_and_split()

# %%
loader = PyPDFLoader("Aayush Sharma.pdf")

# %%
# !pip install pypdf

# %%
doc = loader.load_and_split()

# %%
doc
# Out:
# [Document(metadata={'producer': 'Skia/PDF m145', 'creator': 'FlowCV - https://flowcv.com', 'creationdate': '2026-04-11T14:19:08+00:00', 'moddate': '2026-04-11T14:19:08+00:00', 'keywords': 'FlowCV – Online Resume Builder – https://flowcv.com', 'source': 'Aayush Sharma.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Aayush Sharma\naayushgamer702 @gmail.com\n \n8307757035\n \nAmbala Cantt, Haryana\n \nLinkedIn\n \nGitHub\n \nFinal-year B.Tech (IT) student with hands-on experience in machine learning, deep learning, and natural language \nprocessing. Proficient in Python (Pandas, NumPy, Scikit-learn, TensorFlow, NLTK), SQL, and data analysis. Built \nproduction-ready models with end-to-end data pipelines. Seeking a Data Science or Data Analyst role to deliver data-\ndriven business impact.\nEDUCATION\nB. Tech (Information Technology)\nChandigarh Engineering College, Landran, Mohali | SGPA: 8.2/10\n2022 – 2026\nIntermediate (Class XII) — BSEH\nSanatan Dharma Sen. Sec.
# ...

# %%
vector_store.add_documents(doc)
# Out:
# ['97b86a50-c509-4636-a7f6-605c6938758b']

# %%
vector_store.similarity_search("Aayush Sharma", k=1)
# Out:
# [Document(id='97b86a50-c509-4636-a7f6-605c6938758b', metadata={'producer': 'Skia/PDF m145', 'creator': 'FlowCV - https://flowcv.com', 'creationdate': '2026-04-11T14:19:08+00:00', 'moddate': '2026-04-11T14:19:08+00:00', 'keywords': 'FlowCV – Online Resume Builder – https://flowcv.com', 'source': 'Aayush Sharma.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Aayush Sharma\naayushgamer702 @gmail.com\n \n8307757035\n \nAmbala Cantt, Haryana\n \nLinkedIn\n \nGitHub\n \nFinal-year B.Tech (IT) student with hands-on experience in machine learning, deep learning, and natural language \nprocessing. Proficient in Python (Pandas, NumPy, Scikit-learn, TensorFlow, NLTK), SQL, and data analysis. Built \nproduction-ready models with end-to-end data pipelines. Seeking a Data Science or Data Analyst role to deliver data-\ndriven business impact.\nEDUCATION\nB. Tech (Information Technology)\nChandigarh Engineering College, Landran, Mohali | SGPA: 8.2/10\n2022 – 2026\nIntermediate (
# ...
